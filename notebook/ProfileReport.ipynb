# %%
pip install ydata-profiling
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#    ---------------------------------------- 0.0/678.1 kB ? eta -:--:--
#    ---------------------------------------- 678.1/678.1 kB 8.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    -------------------------- ------------- 2.1/3.1 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------- 3.1/3.1 MB 10.0 MB/s eta 0:00:00
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# ...
#
#    --- ------------------------------------  1/12 [typing-extensions]
#    ------ ---------------------------------  2/12 [PyYAML]
#    ------ ---------------------------------  2/12 [PyYAML]
#    ---------- -----------------------------  3/12 [puremagic]
#    ---------- -----------------------------  3/12 [puremagic]
#    ---------------- -----------------------  5/12 [dacite]
# ...

# %%
from ydata_profiling import ProfileReport
import pandas as pd

# %%
# Step 1: Read your data
df = pd.read_csv("your_file.csv")  # replace with your actual file path
# Generate a profile report

profile = ProfileReport(df, title="My Data Report", explorative=True)

# Save the report as an HTML file
profile.to_file("my_data_report.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# %|          | 0/10 [00:00<?, ?it/s]
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
profile.to_file("my_data_report.html")
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
from IPython.display import IFrame

# Display the HTML report inside the notebook
IFrame(src='my_data_report.html', width=1000, height=600)
# Out:
#         <iframe
#             width="1000"
#             height="600"
#             src="my_data_report.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
